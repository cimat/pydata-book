# %% [markdown]
# # Playing with Pandas

# %%
import pandas as pd
import numpy as np
from pandas import DataFrame, Series
import json
# %matplotlib inline

# %%
# Import data file from a TXT file with JSON entries
data = "../../ch02/usagov_bitly_data2012-03-16-1331923249.txt"
records = [json.loads(line) for line in open(data)]

# %%
records[0]
# Out:
# {u'a': u'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.78 Safari/535.11',
#  u'al': u'en-US,en;q=0.8',
#  u'c': u'US',
#  u'cy': u'Danvers',
#  u'g': u'A6qOVH',
#  u'gr': u'MA',
#  u'h': u'wfLQtf',
#  u'hc': 1331822918,
#  u'hh': u'1.usa.gov',
#  u'l': u'orofrog',
#  u'll': [42.576698, -70.954903],
#  u'nk': 1,
#  u'r': u'http://www.facebook.com/l/7AQEFzjSi/1.usa.gov/wfLQtf',
#  u't': 1331923247,
#  u'tz': u'America/New_York',
#  u'u': u'http://www.ncbi.nlm.nih.gov/pubmed/22415991'}

# %%
records[0]['tz']
# Out:
# u'America/New_York'

# %%
# Importing the JSON data to a data frame
df = DataFrame(records)

# %%
df.head()
# Out:
#    _heartbeat_                                                  a  \
# 0          NaN  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 1          NaN                             GoogleMaps/RochesterNY
# 2          NaN  Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...
# 3          NaN  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...
# 4          NaN  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
#
#                al   c          cy       g  gr       h            hc  \
# 0  en-US,en;q=0.8  US     Danvers  A6qOVH  MA  wfLQtf  1.331823e+09
# 1             NaN  US       Provo  mwszkS  UT  mwszkS  1.308262e+09
# 2           en-US  US  Washington  xxr3Qb  DC  xxr3Qb  1.331920e+09
# 3           pt-br  BR        Braz  zCaLwp  27  zUtuOu  1.331923e+09
# 4  en-US,en;q=0.8  US  Shrewsbury  9b6kNl  MA  9b6kNl  1.273672e+09
#
#           hh   kw         l                        ll   nk  \
# 0  1.usa.gov  NaN   orofrog   [42.576698, -70.954903]  1.0
# ...

# %%
df['tz'][:10]
# Out:
# 0     America/New_York
# 1       America/Denver
# 2     America/New_York
# 3    America/Sao_Paulo
# 4     America/New_York
# 5     America/New_York
# 6        Europe/Warsaw
# 7
# 8
# 9
# Name: tz, dtype: object

# %%
# Counting the top ten time zonez
tz_counts = df['tz'].value_counts()
tz_counts[:10]
# Out:
# America/New_York       1251
#                         521
# America/Chicago         400
# America/Los_Angeles     382
# America/Denver          191
# Europe/London            74
# Asia/Tokyo               37
# Pacific/Honolulu         36
# Europe/Madrid            35
# America/Sao_Paulo        33
# Name: tz, dtype: int64

# %%
# Cleaning the data by marking the empty time zones
clean_tz = df['tz'].fillna('Missing')

# %%
clean_tz[clean_tz == ''] = 'Unknown'

# %%
clean_tz[clean_tz == 'Unknown'].count()
# Out:
# 521

# %%
clean_tz.head(10)
# Out:
# 0     America/New_York
# 1       America/Denver
# 2     America/New_York
# 3    America/Sao_Paulo
# 4     America/New_York
# 5     America/New_York
# 6        Europe/Warsaw
# 7              Unknown
# 8              Unknown
# 9              Unknown
# Name: tz, dtype: object

# %%
tz_counts = clean_tz.value_counts()

# %%
tz_counts[:10]
# Out:
# America/New_York       1251
# Unknown                 521
# America/Chicago         400
# America/Los_Angeles     382
# America/Denver          191
# Missing                 120
# Europe/London            74
# Asia/Tokyo               37
# Pacific/Honolulu         36
# Europe/Madrid            35
# Name: tz, dtype: int64

# %%
# Making a bar plot
tz_counts[:10].plot(kind='barh', rot=0)

# %%
# Parsing the web browsers
results = Series([x.split()[0] for x in df.a.dropna()])

# %%
results[:5]
# Out:
# 0               Mozilla/5.0
# 1    GoogleMaps/RochesterNY
# 2               Mozilla/4.0
# 3               Mozilla/5.0
# 4               Mozilla/5.0
# dtype: object

# %%
results.value_counts()
# Out:
# Mozilla/5.0                                          2594
# Mozilla/4.0                                           601
# GoogleMaps/RochesterNY                                121
# Opera/9.80                                             34
# TEST_INTERNET_AGENT                                    24
# GoogleProducer                                         21
# Mozilla/6.0                                             5
# BlackBerry8520/5.0.0.681                                4
# Dalvik/1.4.0                                            3
# BlackBerry8520/5.0.0.592                                3
# Goldfire                                                2
# Socialite/7766                                          2
# BlackBerry9630/5.0.0.975                                2
# Acoon                                                   2
# BlackBerry9530/5.0.0.328                                1
# Opera/9.64(Windows                                      1
# ...

# %%
# Create a new dataframe where I'll only take the not-null data
cframe = df[df.a.notnull()]

# %%
# Selecting visitors with windows os and non-windows with numpy
os = np.where(cframe.a.str.contains('Windows'),'Windows','Not Windows')

# %%
os[:5]
# Out:
# array(['Windows', 'Not Windows', 'Windows', 'Not Windows', 'Windows'],
#       dtype='|S11')

# %%
by_tz_os = cframe.groupby(['tz', os])

# %%
by_tz_os.head(10)
# Out:
#       _heartbeat_                                                  a  \
# 0             NaN  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 1             NaN                             GoogleMaps/RochesterNY
# 2             NaN  Mozilla/4.0 (compatible; MSIE 8.0; Windows NT ...
# 3             NaN  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...
# 4             NaN  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 5             NaN  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 6             NaN  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.1...
# 7             NaN  Mozilla/5.0 (Windows NT 6.1; rv:2.0.1) Gecko/2...
# 8             NaN  Opera/9.80 (X11; Linux zbov; U; en) Presto/2.1...
# 9             NaN  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...
# 10            NaN  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:10.0.2)...
# 11            NaN  Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10.4...
# 12            NaN  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:10.0.2)...
# ...

# %%
agg_counts = by_tz_os.size().unstack().fillna(0)

# %%
agg_counts[:10]
# Out:
#                                 Not Windows  Windows
# tz
#                                       245.0    276.0
# Africa/Cairo                            0.0      3.0
# Africa/Casablanca                       0.0      1.0
# Africa/Ceuta                            0.0      2.0
# Africa/Johannesburg                     0.0      1.0
# Africa/Lusaka                           0.0      1.0
# America/Anchorage                       4.0      1.0
# America/Argentina/Buenos_Aires          1.0      0.0
# America/Argentina/Cordoba               0.0      1.0
# America/Argentina/Mendoza               0.0      1.0

# %%
indexer = agg_counts.sum(1).argsort()

# %%
indexer[:10]
# Out:
# tz
#                                   24
# Africa/Cairo                      20
# Africa/Casablanca                 21
# Africa/Ceuta                      92
# Africa/Johannesburg               87
# Africa/Lusaka                     53
# America/Anchorage                 54
# America/Argentina/Buenos_Aires    57
# America/Argentina/Cordoba         26
# America/Argentina/Mendoza         55
# dtype: int64

# %%
count_subset = agg_counts.take(indexer)[-10:]

# %%
count_subset
# Out:
#                      Not Windows  Windows
# tz
# America/Sao_Paulo           13.0     20.0
# Europe/Madrid               16.0     19.0
# Pacific/Honolulu             0.0     36.0
# Asia/Tokyo                   2.0     35.0
# Europe/London               43.0     31.0
# America/Denver             132.0     59.0
# America/Los_Angeles        130.0    252.0
# America/Chicago            115.0    285.0
#                            245.0    276.0
# America/New_York           339.0    912.0

# %%
count_subset.plot(kind='barh', stacked=True)

# %%
normed_subset = count_subset.div(count_subset.sum(1), axis=0)

# %%
normed_subset.head()
# Out:
#                    Not Windows   Windows
# tz
# America/Sao_Paulo     0.393939  0.606061
# Europe/Madrid         0.457143  0.542857
# Pacific/Honolulu      0.000000  1.000000
# Asia/Tokyo            0.054054  0.945946
# Europe/London         0.581081  0.418919

# %%
normed_subset.plot(kind='barh', stacked=True)
